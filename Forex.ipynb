# %%
# Set the ticker as 'EURUSD=X'
forex_data = yf.download('EURUSD=X', start='2019-01-02', end='2021-12-31')

# Set the index to a datetime object
forex_data.index = pd.to_datetime(forex_data.index)

# Display the last five rows
forex_data.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Set the ticker as 'EURUSD=X'
# ----> 2 forex_data = yf.download('EURUSD=X', start='2019-01-02', end='2021-12-31')
#       4 # Set the index to a datetime object
#       5 forex_data.index = pd.to_datetime(forex_data.index)
#
# NameError: name 'yf' is not defined

# %%
import yfinance as yf

# %%
# Set the ticker as 'EURUSD=X'
forex_data = yf.download('EURUSD=X', start='2019-01-02', end='2021-12-31')

# Set the index to a datetime object
forex_data.index = pd.to_datetime(forex_data.index)

# Display the last five rows
forex_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 forex_data = yf.download('EURUSD=X', start='2019-01-02', end='2021-12-31')
#       4 # Set the index to a datetime object
# ----> 5 forex_data.index = pd.to_datetime(forex_data.index)
#       7 # Display the last five rows
#       8 forex_data.tail()
#
# NameError: name 'pd' is not defined

# %%
import yfinance as yf
import pandas as pd

# %%
# Set the ticker as 'EURUSD=X'
forex_data = yf.download('EURUSD=X', start='2019-01-02', end='2021-12-31')

# Set the index to a datetime object
forex_data.index = pd.to_datetime(forex_data.index)

# Display the last five rows
forex_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2021-12-24  1.132464  1.134430  1.130838  1.132734   1.132734       0
# 2021-12-27  1.132387  1.133500  1.130416  1.132426   1.132426       0
# 2021-12-28  1.132978  1.133600  1.129038  1.133003   1.133003       0
# 2021-12-29  1.131337  1.137001  1.127536  1.131478   1.131478       0
# 2021-12-30  1.135976  1.135976  1.130071  1.136015   1.136015       0

# %%
# Plot the close price
plt.figure(figsize=(15, 7))
forex_data['Adj Close'].plot()

# Set the title and axis label
plt.title('EUR/USD Data', fontsize=16)
plt.xlabel('Year-Month', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(['Close'], prop={'size': 15})

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Plot the close price
# ----> 2 plt.figure(figsize=(15, 7))
#       3 forex_data['Adj Close'].plot()
#       5 # Set the title and axis label
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# Plot the close price
plt.figure(figsize=(15, 7))
forex_data['Adj Close'].plot()

# Set the title and axis label
plt.title('EUR/USD Data', fontsize=16)
plt.xlabel('Year-Month', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(['Close'], prop={'size': 15})

# Show the plot
plt.show()

# %%
# Set the ticker as 'EURUSD=X'
forex_data_minute = yf.download('EURUSD=X', period='5d', interval='1m')

# Set the index to a datetime object
forex_data_minute.index = pd.to_datetime(forex_data_minute.index)

# Display the last five rows
forex_data_minute.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                Open      High       Low     Close  Adj Close  \
# Datetime
# 2023-08-09 22:18:00+01:00  1.097695  1.097695  1.097695  1.097695   1.097695
# 2023-08-09 22:19:00+01:00  1.097815  1.097815  1.097815  1.097815   1.097815
# 2023-08-09 22:20:00+01:00  1.097936  1.097936  1.097936  1.097936   1.097936
# 2023-08-09 22:21:00+01:00  1.097815  1.097815  1.097815  1.097815   1.097815
# 2023-08-09 22:22:00+01:00  1.097815  1.097815  1.097815  1.097815   1.097815
#
#                            Volume
# Datetime
# 2023-08-09 22:18:00+01:00       0
# 2023-08-09 22:19:00+01:00       0
# 2023-08-09 22:20:00+01:00       0
# 2023-08-09 22:21:00+01:00       0
# 2023-08-09 22:22:00+01:00       0

# %%
# Transform index type from datetime to string
forex_data_minute['dates'] = forex_data_minute.index.strftime(
    '%Y-%m-%d %H:%M:%S')

# Plot the series
fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(forex_data_minute['dates'], forex_data_minute['Adj Close'])

# Set title and axis label
plt.title('EUR/USD Data', fontsize=16)
plt.xlabel('Time', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(['Close'], prop={'size': 15})

# Set maximum number of tick locators
ax.xaxis.set_major_locator(plt.MaxNLocator(10))
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
forex_data_minute.to_csv('forex_data_minute.csv')

# %%
# Print a message to confirm
print("Data exported to forex_data_minute.csv")
# Out:
# Data exported to forex_data_minute.csv
